# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#khoi tao du lieu
means = [[1,5],[4,1],[10,2]]
cov = [[1,0],[0,1]]
N = 500
x1 = np.random.multivariate_normal(means[0], cov, N)
x2 = np.random.multivariate_normal(means[1], cov, N)
x3 = np.random.multivariate_normal(means[2], cov, N)
x1.shape
# Out:
# (500, 2)

# %%
plt.scatter(x1[:,0], x1[:,1], color='red')
plt.scatter(x2[:,0], x2[:,1], color='blue')
plt.scatter(x3[:,0], x3[:,1], color='green')
plt.show()

# %%
#K_means_clustering
#1. Tao ham khoi tao centroid
#2. Co dinh M, tim Y
#3. Co dinh Y, tim M
#4. Kiem tra hoi tu

# %%
#1
def centroid_init(num_k = 3, X):
    centroid_i = np.random.randint()
